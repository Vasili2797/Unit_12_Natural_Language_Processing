# %% [markdown]
# # Unit 12 - Tales from the Crypto
#
# ---

# %% [markdown]
# ## 1. Sentiment Analysis
#
# Use the [newsapi](https://newsapi.org/) to pull the latest news articles for Bitcoin and Ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
import nltk as nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %matplotlib inline
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\nashv\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
from newsapi import NewsApiClient

# %%
# Read your api key environment variable
# YOUR CODE HERE!
load_dotenv('Alpaca.env')

api_key = os.getenv("NEWSAPI_KEY")

print(f"NEWS_API key type: {type(api_key)}")
# Out:
# NEWS_API key type: <class 'str'>

# %%
#print(api_key)

# %%
# Create a newsapi client
# YOUR CODE HERE!
newsapi = NewsApiClient(api_key=api_key)

# %%
# Fetch the Bitcoin news articles
# YOUR CODE HERE!
Bitcoin_headlines = newsapi.get_everything(
    q="bitcoin",
    language="en",
    sort_by="relevancy"
)

# %%
# Fetch the Ethereum news articles
# YOUR CODE HERE!
Ethereum_headlines = newsapi.get_everything(
    q="ethereum AND ETH",
    language="en",
    page_size=100,
    sort_by="relevancy"
)

# %%
# Create the Bitcoin sentiment scores DataFrame
# YOUR CODE HERE!
Bitcoin_sentiments = []

for article in Bitcoin_headlines["articles"]:
    try:
        sentiment = analyzer.polarity_scores(article['content'])
       
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
    
        Bitcoin_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "poitive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
#Bitcoin DataFrame
Bitcoin_df = pd.DataFrame(Bitcoin_sentiments)

# %%
# Create the Ethereum sentiment scores DataFrame
# YOUR CODE HERE!
Ethereum_sentiments = []


for article in Ethereum_headlines["articles"]:
    try:
        
        sentiment = analyzer.polarity_scores(article['content'])
        
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        Ethereum_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "poitive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
#Ethereum DataFrame
Ethereum_df = pd.DataFrame(Ethereum_sentiments)

# %%
#ethereum_articles = Ethereum_headlines  oil_df = pd.DataFrame.from_dict(oil_headlines["articles"])

# %%
Ethereum_df.head()
# Out:
#                                                 text        date  compound  \
# 0  Many investors are excited about the Ethereum ...  2021-04-15    0.3400
# 1  Lately Ive taken greatly to this epaper tablet...  2021-04-08   -0.3041
# 2  March\r\n19, 2021\r\n6 min read\r\nOpinions ex...  2021-03-19    0.7579
# 3  It seems like everyone is making money off of ...  2021-03-29    0.3612
# 4  Opinions expressed by Entrepreneur contributor...  2021-04-08    0.0000
#
#    poitive  negative  neutral
# 0    0.068     0.000    0.932
# 1    0.094     0.145    0.761
# 2    0.183     0.000    0.817
# 3    0.067     0.000    0.933
# 4    0.000     0.000    1.000

# %%
# Describe the Bitcoin Sentiment
# YOUR CODE HERE!
Bitcoin_df.describe()
# Out:
#         compound    poitive  negative    neutral
# count  20.000000  20.000000  20.00000  20.000000
# mean    0.300420   0.080350   0.01490   0.904700
# std     0.288956   0.066469   0.03178   0.081275
# min    -0.381800   0.000000   0.00000   0.709000
# 25%     0.070800   0.047250   0.00000   0.871000
# 50%     0.329100   0.066500   0.00000   0.932500
# 75%     0.432825   0.103750   0.00000   0.940250
# max     0.771700   0.240000   0.10200   1.000000

# %%
Bitcoin_df.head()
# Out:
#                                                 text        date  compound  \
# 0  Whether youre looking to make a larger investm...  2021-03-31    0.0772
# 1  As it promised earlier this year, Tesla now ac...  2021-03-24    0.5859
# 2  The crypto industry as a whole has seen a mome...  2021-04-13    0.6124
# 3  The inevitable has happened: You can now purch...  2021-03-24    0.3182
# 4  Tesla made headlines earlier this year when it...  2021-03-24    0.2023
#
#    poitive  negative  neutral
# 0    0.039       0.0    0.961
# 1    0.127       0.0    0.873
# 2    0.135       0.0    0.865
# 3    0.065       0.0    0.935
# 4    0.050       0.0    0.950

# %%
# Describe the Ethereum Sentiment
# YOUR CODE HERE!
Ethereum_df.describe()
# Out:
#          compound     poitive    negative     neutral
# count  100.000000  100.000000  100.000000  100.000000
# mean     0.307854    0.096370    0.023130    0.880470
# std      0.405231    0.074189    0.039124    0.075006
# min     -0.510600    0.000000    0.000000    0.629000
# 25%      0.000000    0.046500    0.000000    0.840000
# 50%      0.361200    0.081500    0.000000    0.876500
# 75%      0.726900    0.160000    0.049000    0.930000
# max      0.942300    0.371000    0.145000    1.000000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: Bitcoin
#
# Q: Which coin had the highest compound score?
#
# A: Ethereum
#
# Q. Which coin had the highest positive score?
#
# A: Ethereum

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Natural Language Processing
# ---
# ###   Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word.
# 2. Remove Punctuation.
# 3. Remove Stopwords.

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
# Instantiate the lemmatizer
# YOUR CODE HERE!
lemmatizer = WordNetLemmatizer()

# Create a list of stopwords
# YOUR CODE HERE!
Stop_Words = ['https', 'http', 'btc', 'bitcoin', 'eth', 'ethereum']
# Expand the default stopwords list if necessary
More_Stop_Words =['Bitcoin', 'Ethereum', 'BTC', 'ETH']
# YOUR CODE HERE!
sw = set(stopwords.words('english')+Stop_Words+More_Stop_Words)

# %%
#tokenizer("asap, what'sup") => ['asap', 'what', 'sup']
#tokenizer("Hello, my name is mike, how are you?") => ['Hello', 'my', 'name', 'is', 'mike', 'how', 'are', 'you']

# Complete the tokenizer function
def tokenizer(text):
    """Tokenizes text."""
    # Remove the punctuation from text
    regex = re.compile("[^a-zA-Z ]")
    re_clean = regex.sub('', str(text))
    # Create a tokenized list of the words
    words = word_tokenize(re_clean)
    # Lemmatize words into root words
    lem = [lemmatizer.lemmatize(word) for word in words]
    # Convert the words to lowercase
    # Remove the stop words
    tokens = [word.lower() for word in lem if word.lower() not in sw]
    
    
    return tokens

# %%
#first_row_text = Bitcoin_df.iloc[0]["text"]
#first_row_text

# %%
#process_text(first_row_text)

# %%
# Create a new tokens column for Bitcoin
# YOUR CODE HERE!
#Bitcoin_tokens = []
#[Bitcoin_tokens.append(tokenizer(text)) for text in Bitcoin_df]
Bitcoin_df['Tokens'] = Bitcoin_df.apply(lambda row: tokenizer(row.text), axis=1)
#Bitcoin_df = Bitcoin_df.drop(['count'], axis=1)
Bitcoin_df.head()
# Out:
#                                                 text        date  compound  \
# 0  Whether youre looking to make a larger investm...  2021-03-31    0.0772
# 1  As it promised earlier this year, Tesla now ac...  2021-03-24    0.5859
# 2  The crypto industry as a whole has seen a mome...  2021-04-13    0.6124
# 3  The inevitable has happened: You can now purch...  2021-03-24    0.3182
# 4  Tesla made headlines earlier this year when it...  2021-03-24    0.2023
#
#    poitive  negative  neutral  \
# 0    0.039       0.0    0.961
# 1    0.127       0.0    0.873
# 2    0.135       0.0    0.865
# 3    0.065       0.0    0.935
# 4    0.050       0.0    0.950
#
#                                               Tokens
# 0  [whether, youre, looking, make, larger, invest...
# 1  [promised, earlier, year, tesla, accepts, paym...
# 2  [crypto, industry, whole, ha, seen, momentous,...
# 3  [inevitable, ha, happened, purchase, tesla, ve...
# 4  [tesla, made, headline, earlier, year, took, s...

# %%
Ethereum_df
# Out:
#                                                  text        date  compound  \
# 0   Many investors are excited about the Ethereum ...  2021-04-15    0.3400
# 1   Lately Ive taken greatly to this epaper tablet...  2021-04-08   -0.3041
# 2   March\r\n19, 2021\r\n6 min read\r\nOpinions ex...  2021-03-19    0.7579
# 3   It seems like everyone is making money off of ...  2021-03-29    0.3612
# 4   Opinions expressed by Entrepreneur contributor...  2021-04-08    0.0000
# ..                                                ...         ...       ...
# 95  ESillium Home About project How it works About...  2021-03-22    0.0000
# 96  Bitcoin and ether, the two biggest cryptocurre...  2021-04-13    0.0000
# 97  Purpose Investments and CI Global Asset Manage...  2021-04-16    0.6808
# 98  Binance Coin (BNB), the native cryptocurrency ...  2021-04-12    0.7351
# 99  Blockchain security provider Sigma Prime has a...  2021-03-26    0.3400
#
#     poitive  negative  neutral  \
# ...

# %%
# Create a new tokens column for Ethereum
# YOUR CODE HERE!
Ethereum_df['Tokens'] =Ethereum_df.apply(lambda row: tokenizer(row.text), axis=1)
Ethereum_df.head()
# Out:
#                                                 text        date  compound  \
# 0  Many investors are excited about the Ethereum ...  2021-04-15    0.3400
# 1  Lately Ive taken greatly to this epaper tablet...  2021-04-08   -0.3041
# 2  March\r\n19, 2021\r\n6 min read\r\nOpinions ex...  2021-03-19    0.7579
# 3  It seems like everyone is making money off of ...  2021-03-29    0.3612
# 4  Opinions expressed by Entrepreneur contributor...  2021-04-08    0.0000
#
#    poitive  negative  neutral  \
# 0    0.068     0.000    0.932
# 1    0.094     0.145    0.761
# 2    0.183     0.000    0.817
# 3    0.067     0.000    0.933
# 4    0.000     0.000    1.000
#
#                                               Tokens
# 0  [many, investor, excited, network, usessopa, i...
# 1  [lately, ive, taken, greatly, epaper, tablet, ...
# 2  [march, min, readopinions, expressed, entrepre...
# 3  [seems, like, everyone, making, money, nfts, n...
# 4  [opinions, expressed, entrepreneur, contributo...

# %% [markdown]
# ---

# %% [markdown]
# ### NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
# Generate the Bitcoin N-grams where N=2
# YOUR CODE HERE!
N = 2
grams = ngrams(tokenizer(Bitcoin_df.text.str.cat()), N)
Counter(grams).most_common(20)
# Out:
# [(('charsby', 'reuters'), 5),
#  (('earlier', 'year'), 2),
#  (('elon', 'musk'), 2),
#  (('microstrategy', 'inc'), 2),
#  (('inc', 'major'), 2),
#  (('major', 'corporate'), 2),
#  (('corporate', 'backer'), 2),
#  (('backer', 'said'), 2),
#  (('said', 'monday'), 2),
#  (('monday', 'nonemployee'), 2),
#  (('nonemployee', 'director'), 2),
#  (('director', 'get'), 2),
#  (('get', 'fee'), 2),
#  (('fee', 'service'), 2),
#  (('service', 'instead'), 2),
#  (('reuters', 'staffapril'), 2),
#  (('staffapril', 'reuters'), 2),
#  (('world', 'biggest'), 2),
#  (('whether', 'youre'), 1),
#  (('youre', 'looking'), 1)]

# %%
# Generate the Ethereum N-grams where N=2
# YOUR CODE HERE!
#word_count = Counter(Ethereum_df)
N=2
bigram_count = ngrams(tokenizer(Ethereum_df.text.str.cat()), N)
Counter(bigram_count).most_common(20)
#print(dict(bigram_count))
# Out:
# [(('charsbitcoin', 'believer'), 24),
#  (('believer', 'may'), 24),
#  (('may', 'new'), 24),
#  (('new', 'reason'), 24),
#  (('reason', 'rejoice'), 24),
#  (('rejoice', 'following'), 24),
#  (('following', 'stimulus'), 24),
#  (('stimulus', 'check'), 24),
#  (('check', 'ha'), 24),
#  (('ha', 'use'), 24),
#  (('use', 'case'), 24),
#  (('president', 'joe'), 24),
#  (('joe', 'bidens'), 24),
#  (('bidens', 'trillion'), 24),
#  (('trillion', 'covid'), 24),
#  (('covid', 'relief'), 24),
#  (('relief', 'bill'), 24),
#  (('bill', 'ha'), 24),
#  (('ha', 'passed'), 24),
#  (('passed', 'congress'), 24)]

# %%
# Function token_count generates the top 10 words for a given coin
def token_count(tokens, N=3):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Use token_count to get the top 10 words for Bitcoin
# YOUR CODE HERE!
Top_Ten_Bitcoin_Words =tokenizer(Bitcoin_df.text.str.cat())
token_count(Top_Ten_Bitcoin_Words, 10)
# Out:
# [('reuters', 8),
#  ('year', 5),
#  ('tesla', 5),
#  ('ha', 5),
#  ('charsby', 5),
#  ('crypto', 4),
#  ('new', 4),
#  ('according', 3),
#  ('musk', 3),
#  ('said', 3)]

# %%
# Use token_count to get the top 10 words for Ethereum
# YOUR CODE HERE!
Top_Ten_Ethereum_Words = tokenizer(Ethereum_df.text.str.cat())
token_count(Top_Ten_Ethereum_Words, 10)
# Out:
# [('ha', 61),
#  ('new', 31),
#  ('may', 27),
#  ('charsbitcoin', 26),
#  ('use', 26),
#  ('us', 26),
#  ('reason', 25),
#  ('following', 25),
#  ('stimulus', 25),
#  ('believer', 24)]

# %% [markdown]
# ---

# %% [markdown]
# ### Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
# Generate the Bitcoin word cloud
# YOUR CODE HERE!
def wordcloud(text, title=""):
    df_cloud = WordCloud(width=500, colormap='RdYlBu').generate(text)
    plt.imshow(df_cloud)
    plt.axis("off")
    fontdict = {"fontsize": 48, "fontweight" : "bold"}
    plt.title(title, fontdict=fontdict)
    plt.show()

wordcloud(Bitcoin_df.text.str.cat(), title="Bitcoin Word Cloud")

# %%
# Generate the Ethereum word cloud
# YOUR CODE HERE!
wordcloud(Ethereum_df.text.str.cat(), title="Ethereum Word Cloud")

# %% [markdown]
# ---
# ## 3. Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both Bitcoin and Ethereum, then visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Download the language model for SpaCy
# !python -m spacy download en_core_web_sm
# Out:
# ...
# 2021-04-18 03:53:15.591953: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2021-04-18 03:53:15.592026: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# ...
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ---
# ### Bitcoin NER

# %%
# Concatenate all of the Bitcoin text together
# YOUR CODE HERE!
all_concatenated_bitcoin = Bitcoin_df.text.str.cat()
all_concatenated_bitcoin
# Out:
# 'Whether youre looking to make a larger investment or you just want to dabble in cryptocurrencies, you can purchase Bitcoin, Ethereum, Bitcoin Cash, and Litecoin through PayPal. And, soon, youll be ab… [+3818 chars]As it promised earlier this year, Tesla now accepts payment in Bitcoin, according to Tesla\'s website and a tweet from CEO Elon Musk. In a subsequent tweet, Musk said that "Bitcoin paid to Tesla will … [+1390 chars]The crypto industry as a whole has seen a momentous year of growth, heavily spurred on by the entrance of institutional investors adopting bitcoin due to its store of value properties. The 2020 spike… [+4675 chars]The inevitable has happened: You can now purchase a Tesla vehicle with Bitcoin.\xa0\r\nThis is according to Tesla CEO, pardon, Technoking Elon Musk, who tweeted it on Wednesday.\xa0\r\nYou can now buy a Tesla … [+1648 chars]Tesla made headlines earlier this year when it took out significant holdings in bitcoin, acquiring a roughly $1.5 billion stake at
# ...

# %%
# Run the NER processor on all of the text
# YOUR CODE HERE!
bitcoin123 = nlp(all_concatenated_bitcoin)
bitcoin123

# Add a title to the document
# YOUR CODE HERE!

bitcoin123.user_data["Title"] = "Bitcoin NER"

# %%
# Render the visualization
# YOUR CODE HERE!
displacy.render(bitcoin123, style = 'ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Whether youre looking to make a larger investment or you just want to dabble in cryptocurrencies, you can purchase
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin, Ethereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin Cash
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , and Litecoin through PayPal. And, soon, youll be ab… [+3818 chars]As it promised
# ...

# %%
# List all Entities
# YOUR CODE HERE!
for i in bitcoin123.ents:
    print(i.text, i.label_)
# Out:
# Bitcoin, Ethereum ORG
# Bitcoin Cash PERSON
# earlier this year DATE
# Tesla ORG
# Bitcoin PERSON
# Tesla ORG
# Elon Musk PERSON
# Musk PERSON
# Tesla ORG
# a momentous year DATE
# 2020 DATE
# Tesla ORG
# Bitcoin PERSON
# Elon Musk PERSON
# Wednesday DATE
# earlier this year DATE
# roughly $1.5 billion MONEY
# early February DATE
# SEC ORG
# Burrito Day PERSON
# April Fools Day DATE
# this year DATE
# tomorrow DATE
# Pollo Loco FAC
# a big year DATE
# Robinhood ORG
# today DATE
# Christine Brown PERSON
# Robinhoods PERSON
# Reuters ORG
# Reuters ORG
# Inc PERSON
# Monday DATE
# millions CARDINAL
# Reuters ORG
# April 12 DATE
# Reuters ORG
# Monday DATE
# Funko PERSON
# NFT ORG
# TokenWave ORG
# 23, 2021 DATE
# Spanish NORP
# AI ORG
# Bitcoin PERSON
# the United States GPE
# FD Funds Management LLC ORG
# PayPal PERSON
# Julian Satterthwaite PERSON
# Reuters ORG
# April 18 DATE
# Reuters ORG
# 7.7% PERCENT
# 55,408.08 MONEY
# Sunday DATE
# 4,624.21 MONEY
# Reuters ORG
# LONDON GPE
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### Ethereum NER

# %%
# Concatenate all of the Ethereum text together
# YOUR CODE HERE!
all_concatenated_Ethereum = Ethereum_df.text.str.cat()
all_concatenated_Ethereum
# Out:
# 'Many investors are excited about the Ethereum network\'s uses.\r\nSOPA Images/Getty Images\r\nEther soared to an all-time high above $2,400 on Thursday in the wake of the $100 billion Coinbase direct list… [+1923 chars]Lately Ive taken greatly to this epaper tablet, the ReMarkable 2. Im not sure who sells it. Not Apple or Amazon. Its slower and monochrome and less powerful than my iPad, but somehow its duller, pape… [+3520 chars]March\r\n19, 2021\r\n6 min read\r\nOpinions expressed by Entrepreneur contributors are their own.\r\nOne of the beautiful things about decentralized finance (DeFi)\xa0is the opportunities it provides for earnin… [+6787 chars]It seems like everyone is making money off of NFTs, or non-fungible tokens, those digital artworks that have been labeled the next investment mania. Everyone, that is, except for you. Its the same fe… [+5036 chars]Opinions expressed by Entrepreneur contributors are their own.\r\nThe crypto market moves in waves. Bitcoin remains the undis
# ...

# %%
# Run the NER processor on all of the text
# YOUR CODE HERE!
ethereum =nlp(all_concatenated_Ethereum)
# Add a title to the document
# YOUR CODE HERE!
ethereum.user_data["title"] = "Ethereum NER"

# %%
# Render the visualization
# YOUR CODE HERE!
displacy.render(ethereum, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Ethereum NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Many investors are excited about the
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>SOPA
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Images/Getty Images
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>Ether soared to an all-time high
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
# ...

# %%
# List all Entities
# YOUR CODE HERE!
for i in ethereum.ents:
    print(i.text, i.label_)
# Out:
# Ethereum PERSON
# Images/Getty Images ORG
# above $2,400 MONEY
# Thursday DATE
# $100 billion MONEY
# Apple ORG
# Amazon ORG
# iPad ORG
# 19, 2021 DATE
# Entrepreneur ORG
# Entrepreneur ORG
# Bitcoin PERSON
# NFT ORG
# Ethereum ORG
# more than $224 million MONEY
# 2021 DATE
# OpenSea NORP
# above $2,700 MONEY
# Kraken ORG
# Kraken ORG
# Pete Humiston PERSON
# 35% PERCENT
# March DATE
# Kraken ORG
# Dado Ruvic PERSON
# Reuters ORG
# above $2,700 MONEY
# Segal PERSON
# Burn Alpha FAC
# Mirror ORG
# 0.1 CARDINAL
# ETH ORG
# yesterday DATE
# evening TIME
# 25 CARDINAL
# ETH ORG
# 1990 DATE
# millions of dollars MONEY
# two CARDINAL
# second ORDINAL
# Friday DATE
# above $2,000 MONEY
# +4.12% PERCENT
# nearly 7% PERCENT
# around $2,069 MONEY
# last Monday DATE
# 40,671 CARDINAL
# Bitcoin PERSON
# first ORDINAL
# chars]0.5% PERCENT
# 4/5 CARDINAL
# roughly 12% PERCENT
# 4/5 CARDINAL
# 35 CARDINAL
# Dogecoin GPE
# first ORDINAL
# Spanish NORP
# AI ORG
# Entrepreneur ORG
# the summer DATE
# ...

# %% [markdown]
# ---
